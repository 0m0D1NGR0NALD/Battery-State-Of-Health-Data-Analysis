# %%
# importing libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# importing dataset
dataset = pd.read_csv('BSOH.csv',low_memory=False)
# Creating dataframe
df = pd.DataFrame(dataset)

# %%
# number of null cells in dataset
dataset.isnull().sum()
# Out:
# IMEI                   389039
# Supply Voltage         389039
# Supply Current         389039
# Battery Voltage        389039
# Panel Voltage          389039
# Panel Current          389039
# Room Temperature       389039
# Battery Temperature    389039
# Timestamp              389039
# Hour                        0
# Minute                      0
# T D(s)                      0
# I E(Wh)                     0
# O C(A)                      0
# O E(Ah)                     0
# SOH(%)                      0
# dtype: int64

# %%
# Heatmap of null data in dataset
sns.heatmap(dataset.isnull(),yticklabels= False,cmap='Accent')
# Out:
# <AxesSubplot:>

# %%
# Dropping all null rows of data
dataset.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# IMEI                   389039
# Supply Voltage         389039
# Supply Current         389039
# Battery Voltage        389039
# Panel Voltage          389039
# Panel Current          389039
# Room Temperature       389039
# Battery Temperature    389039
# Timestamp              389039
# Hour                        0
# Minute                      0
# T D(s)                      0
# I E(Wh)                     0
# O C(A)                      0
# O E(Ah)                     0
# SOH(%)                      0
# dtype: int64

# %%
# Heatmap of null cells in dataframe
sns.heatmap(df.isnull(),yticklabels= False,cmap='Accent')
# Out:
# <AxesSubplot:>

# %%
# Drop null rows in dataframe
df.dropna(inplace=True)

# %%
# Checking null cells in dataframe
df.isnull().sum()
# Out:
# IMEI                   0
# Supply Voltage         0
# Supply Current         0
# Battery Voltage        0
# Panel Voltage          0
# Panel Current          0
# Room Temperature       0
# Battery Temperature    0
# Timestamp              0
# Hour                   0
# Minute                 0
# T D(s)                 0
# I E(Wh)                0
# O C(A)                 0
# O E(Ah)                0
# SOH(%)                 0
# dtype: int64

# %%
df.describe()
# Out:
#                IMEI  Supply Voltage  Supply Current  Battery Voltage  \
# count  6.595360e+05   659536.000000   659536.000000    659536.000000
# mean   8.610000e+14       11.410905        2.652556        11.410905
# std    8.296256e+03        2.224166        1.930480         2.224166
# min    8.610000e+14        8.150000        0.000000         8.150000
# 25%    8.610000e+14        8.890000        0.500000         8.890000
# 50%    8.610000e+14       12.290000        2.970000        12.290000
# 75%    8.610000e+14       13.510000        3.950000        13.510000
# max    8.610000e+14       14.530000       17.770000        14.530000
#
#        Panel Voltage  Panel Current  Room Temperature  Battery Temperature
# count  659536.000000  659536.000000          659536.0             659536.0
# mean       11.188658       2.990345               0.0                  0.0
# std         2.281558       2.430904               0.0                  0.0
# ...

# %%
# Displaying top 5 rows in dataframe
df.head()
# Out:
#            IMEI  Supply Voltage  Supply Current  Battery Voltage  \
# 0  8.610000e+14            8.77            4.45             8.77
# 1  8.610000e+14            8.77            4.45             8.77
# 2  8.610000e+14            8.77            3.95             8.77
# 3  8.610000e+14            8.77            4.45             8.77
# 4  8.610000e+14            8.77            4.94             8.77
#
#    Panel Voltage  Panel Current  Room Temperature  Battery Temperature  \
# 0           8.60           2.96               0.0                  0.0
# 1           8.60           3.95               0.0                  0.0
# 2           8.63           3.45               0.0                  0.0
# 3           8.60           2.96               0.0                  0.0
# 4           8.63           2.96               0.0                  0.0
#
#        Timestamp Hour Minute T D(s) I E(Wh) O C(A) O E(Ah) SOH(%)
# 0  1/1/2021 0:00    0      0      0       0   4.23       0      0
# ...

# %%
# Allocating columns to variables using indexing functions
X = df.iloc[:, -5].values
y = df.iloc[:, 3].values

# %%
# Sorting dataframe values by SOH in ascending order and printing top 10 values 
df.sort_values(by = 'SOH(%)', ascending = False).head(10)
# Out:
#                 IMEI  Supply Voltage  Supply Current  Battery Voltage  \
# 610998  8.610000e+14            8.91            3.95             8.91
# 609074  8.610000e+14            8.99            3.95             8.99
# 55223   8.610000e+14           12.61            2.97            12.61
# 383683  8.610000e+14           14.25            1.98            14.25
# 389578  8.610000e+14            8.71            1.48             8.71
# 401159  8.610000e+14            8.59            1.98             8.59
# 223159  8.610000e+14            8.75            4.45             8.75
# 202976  8.610000e+14           12.85            4.45            12.85
# 21149   8.610000e+14            8.47            4.45             8.47
# 284774  8.610000e+14           10.01            4.45            10.01
#
#         Panel Voltage  Panel Current  Room Temperature  Battery Temperature  \
# 610998           8.77           3.95               0.0                  0.0
# ...

# %%
df.sort_values(by = 'O E(Ah)', ascending = False).head(10)
# Out:
#                 IMEI  Supply Voltage  Supply Current  Battery Voltage  \
# 610998  8.610000e+14            8.91            3.95             8.91
# 609074  8.610000e+14            8.99            3.95             8.99
# 165283  8.610000e+14            8.31            4.45             8.31
# 614863  8.610000e+14            8.43            3.95             8.43
# 618749  8.610000e+14            9.09            3.95             9.09
# 616797  8.610000e+14            8.59            3.46             8.59
# 280279  8.610000e+14           12.49            4.94            12.49
# 593340  8.610000e+14           14.23            3.95            14.23
# 170021  8.610000e+14           12.85            4.94            12.85
# 387016  8.610000e+14           12.51            3.46            12.51
#
#         Panel Voltage  Panel Current  Room Temperature  Battery Temperature  \
# 610998           8.77           3.95               0.0                  0.0
# ...

# %%
# Max of Output Energy
df['O E(Ah)'].max()
# Out:
# '9.76'

# %%
# Calculating mean of SOH
#df['SOH(%)'].mean()

# %%
# plt.scatter(X,y)
# plt.title('The Discharge Curve')
# plt.xlabel('SOH(%)')
# plt.ylabel('Battery Voltage')
# plt.show()

# %%
# sns.set()
# df1 = pd.DataFrame(df,columns=['Battery Voltage', 'SOH(%)'])
# graph = sns.scatterplot(x='Battery Voltage', y='SOH(%)', data=df1)

# %%
# Scatterplot of Time difference against Supply Voltage
sns.scatterplot(x = df['T D(s)'], y = df['Supply Voltage'])
# Out:
# <AxesSubplot:xlabel='T D(s)', ylabel='Supply Voltage'>

# %%
# Scatterplot of Time difference against Supply Current
sns.scatterplot(x = df['T D(s)'], y = df['Supply Current'])
# Out:
# <AxesSubplot:xlabel='T D(s)', ylabel='Supply Current'>

# %%
sns.lineplot(x=df['T D(s)'], y=df['Supply Current'])
# Out:
# <AxesSubplot:xlabel='T D(s)', ylabel='Supply Current'>

# %%
# Scatterplot of Time difference against Battery Voltage
sns.scatterplot(x = df['T D(s)'], y = df['Battery Voltage'])
# Out:
# <AxesSubplot:xlabel='T D(s)', ylabel='Battery Voltage'>

# %%
sns.lineplot(x=df['T D(s)'], y=df['Battery Voltage'])
# Out:
# <AxesSubplot:xlabel='T D(s)', ylabel='Battery Voltage'>

# %%
# Scatterplot of Time difference against Panel voltage
sns.scatterplot(x = df['T D(s)'], y = df['Panel Voltage'])
# Out:
# <AxesSubplot:xlabel='T D(s)', ylabel='Panel Voltage'>

# %%
# Scatterplot of Time difference against Panel Current
sns.scatterplot(x = df['T D(s)'], y = df['Panel Current'])
# Out:
# <AxesSubplot:xlabel='T D(s)', ylabel='Panel Current'>

# %%
# 5 by 1 subplot of barplots comparing time difference against
#supply voltage, 
#supply current, 
#battery voltage, 
#panel voltage, 
#panel current.
plt.subplot(5,1,1)
sns.barplot(data = df, x = df['T D(s)'], y = df['Supply Voltage'])
plt.subplot(5,1,2)
sns.barplot(data = df, x = df['T D(s)'], y = df['Supply Current'])
plt.subplot(5,1,3)
sns.barplot(data = df, x = df['T D(s)'], y = df['Battery Voltage'])
plt.subplot(5,1,4)
sns.barplot(data = df, x = df['T D(s)'], y = df['Panel Voltage'])
plt.subplot(5,1,5)
sns.barplot(data = df, x = df['T D(s)'], y = df['Panel Current'])
# Out:
# <AxesSubplot:xlabel='T D(s)', ylabel='Panel Current'>

# %%
# Barplot of time difference against Supply Voltage
sns.barplot(x = df['T D(s)'], y = df['Supply Voltage'])
# Out:
# <AxesSubplot:xlabel='T D(s)', ylabel='Supply Voltage'>

# %%
# Barplot of time difference against Supply Current
sns.barplot(x = df['T D(s)'], y = df['Supply Current'])
# Out:
# <AxesSubplot:xlabel='T D(s)', ylabel='Supply Current'>

# %%
# Barplot of time difference against Battery Voltage
sns.barplot(x = df['T D(s)'], y = df['Battery Voltage'])
# Out:
# <AxesSubplot:xlabel='T D(s)', ylabel='Battery Voltage'>

# %%
# Barplot of time difference against Panel Voltage
sns.barplot(x = df['T D(s)'], y = df['Panel Voltage'])
# Out:
# <AxesSubplot:xlabel='T D(s)', ylabel='Panel Voltage'>

# %%
# Barplot of time difference against Panel Current
sns.barplot(x = df['T D(s)'], y = df['Panel Current'])
# Out:
# <AxesSubplot:xlabel='T D(s)', ylabel='Panel Current'>

# %%
# Mean of Supply Voltage
df['Supply Voltage'].mean()
# Out:
# 11.410904666315279

# %%
df['Supply Voltage'].describe()
# Out:
# count    659536.000000
# mean         11.410905
# std           2.224166
# min           8.150000
# 25%           8.890000
# 50%          12.290000
# 75%          13.510000
# max          14.530000
# Name: Supply Voltage, dtype: float64

# %%
# Mean of Supply Current
df['Supply Current'].mean()
# Out:
# 2.65255570581341

# %%
df['Supply Current'].mean()
# Out:
# 2.65255570581341

# %%
df['Supply Current'].describe()
# Out:
# count    659536.000000
# mean          2.652556
# std           1.930480
# min           0.000000
# 25%           0.500000
# 50%           2.970000
# 75%           3.950000
# max          17.770000
# Name: Supply Current, dtype: float64

# %%
# Mean of Battery Voltage
df['Battery Voltage'].mean()
# Out:
# 11.410904666315279

# %%
df['Battery Voltage'].describe()
# Out:
# count    659536.000000
# mean         11.410905
# std           2.224166
# min           8.150000
# 25%           8.890000
# 50%          12.290000
# 75%          13.510000
# max          14.530000
# Name: Battery Voltage, dtype: float64

# %%
# Mean of Panel Voltage
df['Panel Voltage'].mean()
# Out:
# 11.18865795043757

# %%
df['Panel Voltage'].describe()
# Out:
# count    659536.000000
# mean         11.188658
# std           2.281558
# min           4.560000
# 25%           8.700000
# 50%          11.920000
# 75%          13.390000
# max          14.800000
# Name: Panel Voltage, dtype: float64

# %%
# Mean of Panel Current
df['Panel Current'].mean()
# Out:
# 2.9903450304257335

# %%
df['Panel Current'].describe()
# Out:
# count    659536.000000
# mean          2.990345
# std           2.430904
# min           0.000000
# 25%           0.000000
# 50%           3.950000
# 75%           4.440000
# max          14.310000
# Name: Panel Current, dtype: float64

# %%
sns.histplot(data=df, x= df['T D(s)'])
# Out:
# <AxesSubplot:xlabel='T D(s)', ylabel='Count'>

# %%
df['T D(s)'].mean()
# Out:
# inf

# %%
df['T D(s)'].describe()
# Out:
# count     659536
# unique       116
# top           60
# freq      417653
# Name: T D(s), dtype: object

# %%
df['T D(s)'].max()
# Out:
# '9960'

# %%
df.sort_values(by = 'T D(s)', ascending = False).head(10)
# Out:
#                 IMEI  Supply Voltage  Supply Current  Battery Voltage  \
# 167184  8.610000e+14            8.31            4.45             8.31
# 517537  8.610000e+14           14.09            0.00            14.09
# 409023  8.610000e+14           13.49            0.00            13.49
# 602726  8.610000e+14           13.85            3.46            13.85
# 438103  8.610000e+14           12.57            0.00            12.57
# 405968  8.610000e+14           12.63            2.97            12.63
# 204872  8.610000e+14           13.21            4.94            13.21
# 403628  8.610000e+14           14.21            1.48            14.21
# 551924  8.610000e+14           14.23            0.00            14.23
# 258649  8.610000e+14           14.29            2.47            14.29
#
#         Panel Voltage  Panel Current  Room Temperature  Battery Temperature  \
# 167184           8.08           4.44               0.0                  0.0
# ...

# %%
df.sort_values(by = 'Battery Voltage', ascending = True).head(10)
# Out:
#                 IMEI  Supply Voltage  Supply Current  Battery Voltage  \
# 2237    8.610000e+14            8.15            3.95             8.15
# 196001  8.610000e+14            8.17            3.95             8.17
# 147941  8.610000e+14            8.17            3.95             8.17
# 179616  8.610000e+14            8.17            4.94             8.17
# 221539  8.610000e+14            8.17            4.45             8.17
# 198376  8.610000e+14            8.19            3.95             8.19
# 198360  8.610000e+14            8.19            4.45             8.19
# 255664  8.610000e+14            8.19            1.48             8.19
# 215318  8.610000e+14            8.19            3.46             8.19
# 266443  8.610000e+14            8.21            2.97             8.21
#
#         Panel Voltage  Panel Current  Room Temperature  Battery Temperature  \
# 2237             7.98           2.96               0.0                  0.0
# ...

# %%
df.sort_values(by = 'SOH(%)', ascending = False).head(10)
# Out:
#                 IMEI  Supply Voltage  Supply Current  Battery Voltage  \
# 610998  8.610000e+14            8.91            3.95             8.91
# 609074  8.610000e+14            8.99            3.95             8.99
# 55223   8.610000e+14           12.61            2.97            12.61
# 383683  8.610000e+14           14.25            1.98            14.25
# 389578  8.610000e+14            8.71            1.48             8.71
# 401159  8.610000e+14            8.59            1.98             8.59
# 223159  8.610000e+14            8.75            4.45             8.75
# 202976  8.610000e+14           12.85            4.45            12.85
# 21149   8.610000e+14            8.47            4.45             8.47
# 284774  8.610000e+14           10.01            4.45            10.01
#
#         Panel Voltage  Panel Current  Room Temperature  Battery Temperature  \
# 610998           8.77           3.95               0.0                  0.0
# ...

# %%
df.sort_values(by = 'Hour', ascending = False).head(10)
# Out:
#                 IMEI  Supply Voltage  Supply Current  Battery Voltage  \
# 382241  8.610000e+14           12.51            4.94            12.51
# 26307   8.610000e+14            9.21            4.45             9.21
# 604482  8.610000e+14            9.09            3.95             9.09
# 544322  8.610000e+14            8.45            0.00             8.45
# 479266  8.610000e+14           12.45            0.99            12.45
# 550871  8.610000e+14            9.09            0.50             9.09
# 477601  8.610000e+14           10.05            1.98            10.05
# 516671  8.610000e+14            8.71            0.00             8.71
# 554134  8.610000e+14            8.63            0.00             8.63
# 523251  8.610000e+14            8.85            0.00             8.85
#
#         Panel Voltage  Panel Current  Room Temperature  Battery Temperature  \
# 382241          12.19           0.00               0.0                  0.0
# ...

# %%
sns.scatterplot(x=df['T D(s)'], y=df['SOH(%)'])
# Out:
# <AxesSubplot:xlabel='T D(s)', ylabel='SOH(%)'>

# %%
sns.lineplot(x=df['T D(s)'], y=df['SOH(%)'])
# Out:
# <AxesSubplot:xlabel='T D(s)', ylabel='SOH(%)'>

# %%
sns.histplot(x=df['T D(s)'], y=df['SOH(%)'])
# Out:
# <AxesSubplot:xlabel='T D(s)', ylabel='SOH(%)'>

# %%
# Eliminating rows when T D(s) = 0
data_1 = df[df['T D(s)'] != '0']
data_1
# Out:
#                 IMEI  Supply Voltage  Supply Current  Battery Voltage  \
# 2       8.610000e+14            8.77            3.95             8.77
# 3       8.610000e+14            8.77            4.45             8.77
# 5       8.610000e+14            8.75            3.95             8.75
# 6       8.610000e+14            8.75            4.45             8.75
# 7       8.610000e+14            8.73            3.95             8.73
# ...              ...             ...             ...              ...
# 659529  8.610000e+14           10.55            6.42            10.55
# 659531  8.610000e+14           10.51            5.93            10.51
# 659532  8.610000e+14           10.49            6.42            10.49
# 659534  8.610000e+14           10.47            5.93            10.47
# 659535  8.610000e+14           10.47            5.93            10.47
#
#         Panel Voltage  Panel Current  Room Temperature  Battery Temperature  \
# ...

# %%
# Eliminating rows when T D(s) != 0
data_2 = df[df['T D(s)'] == '0']
data_2
# Out:
#                 IMEI  Supply Voltage  Supply Current  Battery Voltage  \
# 0       8.610000e+14            8.77            4.45             8.77
# 1       8.610000e+14            8.77            4.45             8.77
# 4       8.610000e+14            8.77            4.94             8.77
# 9       8.610000e+14            8.73            4.45             8.73
# 11      8.610000e+14            8.73            3.95             8.73
# ...              ...             ...             ...              ...
# 659521  8.610000e+14           10.59            5.93            10.59
# 659524  8.610000e+14           10.59            5.43            10.59
# 659528  8.610000e+14           10.55            6.42            10.55
# 659530  8.610000e+14           10.53            5.93            10.53
# 659533  8.610000e+14           10.47            5.43            10.47
#
#         Panel Voltage  Panel Current  Room Temperature  Battery Temperature  \
# ...

# %%
sns.lineplot(x=data_1['T D(s)'], y=data_1['SOH(%)'],hue_order='Timestamp')
# Out:
# <AxesSubplot:xlabel='T D(s)', ylabel='SOH(%)'>

# %%
# Eliminating rows when SOH(%) < 100
data_3 = df[df['SOH(%)'] > '100.0']
data_3.sort_values(by = 'SOH(%)', ascending = False).head(10)
# Out:
#                 IMEI  Supply Voltage  Supply Current  Battery Voltage  \
# 610998  8.610000e+14            8.91            3.95             8.91
# 609074  8.610000e+14            8.99            3.95             8.99
# 55223   8.610000e+14           12.61            2.97            12.61
# 383683  8.610000e+14           14.25            1.98            14.25
# 389578  8.610000e+14            8.71            1.48             8.71
# 401159  8.610000e+14            8.59            1.98             8.59
# 21149   8.610000e+14            8.47            4.45             8.47
# 202976  8.610000e+14           12.85            4.45            12.85
# 95598   8.610000e+14           12.65            4.45            12.65
# 284774  8.610000e+14           10.01            4.45            10.01
#
#         Panel Voltage  Panel Current  Room Temperature  Battery Temperature  \
# 610998           8.77           3.95               0.0                  0.0
# ...

# %%
sns.lineplot(x=data_3['T D(s)'], y=np.sort(data_3['SOH(%)']))
# Out:
# <AxesSubplot:xlabel='T D(s)'>

# %%
sns.scatterplot(x=data_3['T D(s)'], y=np.sort(data_3['SOH(%)']))
# Out:
# <AxesSubplot:xlabel='T D(s)'>

# %%
# Eliminating rows when SOH(%) > 100
data_4 = df[df['SOH(%)'] < '100.0']
data_4.sort_values(by = 'SOH(%)', ascending = False)
# Out:
#                 IMEI  Supply Voltage  Supply Current  Battery Voltage  \
# 400562  8.610000e+14           12.61            4.45            12.61
# 11814   8.610000e+14           12.41            3.95            12.41
# 75757   8.610000e+14           10.45            1.48            10.45
# 297501  8.610000e+14           12.37            4.94            12.37
# 187922  8.610000e+14            8.45            4.94             8.45
# ...              ...             ...             ...              ...
# 434598  8.610000e+14           12.47            0.00            12.47
# 434597  8.610000e+14           12.49            0.00            12.49
# 434596  8.610000e+14           12.47            0.00            12.47
# 434595  8.610000e+14           12.49            0.00            12.49
# 0       8.610000e+14            8.77            4.45             8.77
#
#         Panel Voltage  Panel Current  Room Temperature  Battery Temperature  \
# ...

# %%
sns.lineplot(x=data_4['T D(s)'], y=data_4['SOH(%)'])
# Out:
# <AxesSubplot:xlabel='T D(s)', ylabel='SOH(%)'>

# %%
sns.scatterplot(x=data_4['T D(s)'], y=np.sort(data_4['SOH(%)']))
# Out:
# <AxesSubplot:xlabel='T D(s)'>

# %%
from bokeh.plotting import figure,show
from bokeh.models import HoverTool 

TOOLTIPS = HoverTool(tooltips=[('index', '$index'), ('(SOH(%),T D(s))', '(@SOH(%),@T D(s))')])

p = figure(title='SOH(%) vs T D(s)', x_axis_label='T D(s)', y_axis_label='SOH(%)', plot_width=700, plot_height=700, tools=[TOOLTIPS])
p.circle('T D(s)', 'SOH(%)', size =10, source = data_1)
show(p)

# %%
ndata = df[df['SOH(%)']>'50']
ndata
# Out:
#                 IMEI  Supply Voltage  Supply Current  Battery Voltage  \
# 132     8.610000e+14            8.67            3.95             8.67
# 174     8.610000e+14            8.57            3.95             8.57
# 9615    8.610000e+14           12.83            4.94            12.83
# 21149   8.610000e+14            8.47            4.45             8.47
# 25916   8.610000e+14           12.59            3.95            12.59
# ...              ...             ...             ...              ...
# 616797  8.610000e+14            8.59            3.46             8.59
# 618749  8.610000e+14            9.09            3.95             9.09
# 631187  8.610000e+14           14.15            3.46            14.15
# 636471  8.610000e+14            8.75            3.46             8.75
# 636885  8.610000e+14            8.31            3.46             8.31
#
#         Panel Voltage  Panel Current  Room Temperature  Battery Temperature  \
# ...

# %%
sns.lineplot(x=data_1['T D(s)'], y=data_1['SOH(%)'])
# Out:
# <AxesSubplot:xlabel='T D(s)', ylabel='SOH(%)'>

# %%
sns.lineplot(x=data_1['T D(s)'], y=data_1['Battery Voltage'])
# Out:
# <AxesSubplot:xlabel='T D(s)', ylabel='Battery Voltage'>

# %%
# Comparing Battery Voltage against State of Health using a line plot
sns.lineplot(x=data_1['Battery Voltage'], y=data_1['SOH(%)'])
# Out:
# <AxesSubplot:xlabel='Battery Voltage', ylabel='SOH(%)'>

# %%
# Comparing Battery Voltage against State of Health using a scatter plot
sns.scatterplot(x=data_1['Battery Voltage'], y=data_1['SOH(%)'])
# Out:
# <AxesSubplot:xlabel='Battery Voltage', ylabel='SOH(%)'>

# %%
# Comparing State of Health against Battery Voltage using a scatter plot
sns.scatterplot(x=data_1['SOH(%)'], y=data_1['Battery Voltage'])
# Out:
# <AxesSubplot:xlabel='SOH(%)', ylabel='Battery Voltage'>

# %%
# Comparing Battery Voltage against State of Health using a line plot
sns.lineplot(x=data_1['SOH(%)'], y=data_1['Battery Voltage'])
# Out:
# <AxesSubplot:xlabel='SOH(%)', ylabel='Battery Voltage'>

# %%
data_1.columns.get_loc('T D(s)')
# Out:
# 11

# %%
data_1.columns.get_loc('Battery Voltage')
# Out:
# 3

# %%
data_1.columns.get_loc('SOH(%)')
# Out:
# 15

# %%
X = data_1.iloc[:,[3,11,15]].values
X
# Out:
# array([[8.77, '60', '0.6'],
#        [8.77, '60', '0.7'],
#        [8.75, '300', '3.1'],
#        ...,
#        [10.49, '60', '1'],
#        [10.47, '60', '0.9'],
#        [10.47, '60', '0.9']], dtype=object)

# %%
# Comparing time difference against State of Health using a line plot
sns.lineplot(x=data_1['SOH(%)'], y=data_1['T D(s)'])
# Out:
# <AxesSubplot:xlabel='SOH(%)', ylabel='T D(s)'>

# %%
sns.lineplot(x=np.sort(data_3['SOH(%)']), y=data_3['O C(A)'])
# Out:
# <AxesSubplot:ylabel='O C(A)'>

# %%
# Comparing time difference against State of Health using a line plot
sns.lineplot(x=data_3['O E(Ah)'], y=data_3['SOH(%)'])
# Out:
# <AxesSubplot:xlabel='O E(Ah)', ylabel='SOH(%)'>
